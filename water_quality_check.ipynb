# %%
#Import pandas, matplotlib.pyplot, and seaborn in the correct lines below
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import RepeatedStratifiedKFold
from sklearn.model_selection import cross_val_score

# %%
# the supplied CSV data file is the raw_data directory
water_data = pd.read_csv('C:/Users/monal/Desktop/Data Science/Water Quality/water_potability.csv')

# %%
#1 is potable, 0 is nonpotable
water_data.dropna(inplace = True)
water_data.head()
# Out:
#           ph    Hardness        Solids  Chloramines     Sulfate  Conductivity  \
# 3   8.316766  214.373394  22018.417441     8.059332  356.886136    363.266516
# 4   9.092223  181.101509  17978.986339     6.546600  310.135738    398.410813
# 5   5.584087  188.313324  28748.687739     7.544869  326.678363    280.467916
# 6  10.223862  248.071735  28749.716544     7.513408  393.663396    283.651634
# 7   8.635849  203.361523  13672.091764     4.563009  303.309771    474.607645
#
#    Organic_carbon  Trihalomethanes  Turbidity  Potability
# 3       18.436524       100.341674   4.628771           0
# 4       11.558279        31.997993   4.075075           0
# 5        8.399735        54.917862   2.559708           0
# 6       13.789695        84.603556   2.672989           0
# 7       12.363817        62.798309   4.401425           0

# %%
#Turbidity check
#sns.stripplot(x='Potability', y='Turbidity', data=water_data);
water_data["all"] = ""
sns.violinplot(x="all", y="Turbidity", hue="Potability", data=water_data, split=True)
plt.xlabel('Potability')
# Out:
# Text(0.5, 0, 'Potability')

# %%
#pH check
#sns.stripplot(x='Potability', y='ph', data=water_data);
sns.violinplot(x="all", y="ph", hue="Potability", data=water_data, split=True)
plt.xlabel('Potability')
# Out:
# Text(0.5, 0, 'Potability')

# %%
#Hardness check
#sns.stripplot(x='Potability', y='Hardness', data=water_data);
sns.violinplot(x="all", y="Hardness", hue="Potability", data=water_data, split=True)
plt.xlabel('Potability')
# Out:
# Text(0.5, 0, 'Potability')

# %%
#solids check
#sns.stripplot(x='Potability', y='Solids', data=water_data);
sns.violinplot(x="all", y="Solids", hue="Potability", data=water_data, split=True)
plt.xlabel('Potability')
# Out:
# Text(0.5, 0, 'Potability')

# %%
#Chloramines check
#sns.stripplot(x='Potability', y='Chloramines', data=water_data);
sns.violinplot(x="all", y="Chloramines", hue="Potability", data=water_data, split=True)
plt.xlabel('Potability')
# Out:
# Text(0.5, 0, 'Potability')

# %%
#Sulfate check
#sns.stripplot(x='Potability', y='Sulfate', data=water_data);
sns.violinplot(x="all", y="Sulfate", hue="Potability", data=water_data, split=True)
plt.xlabel('Potability')
# Out:
# Text(0.5, 0, 'Potability')

# %%
#Conductivity check
#sns.stripplot(x='Potability', y='Conductivity', data=water_data);
sns.violinplot(x="all", y="Conductivity", hue="Potability", data=water_data, split=True)
plt.xlabel('Potability')
# Out:
# Text(0.5, 0, 'Potability')

# %%
#Carbon check
#sns.stripplot(x='Potability', y='Organic_carbon', data=water_data);
sns.violinplot(x="all", y="Organic_carbon", hue="Potability", data=water_data, split=True)
plt.xlabel('Potability')
# Out:
# Text(0.5, 0, 'Potability')

# %%
#THM check
#sns.stripplot(x='Potability', y='Trihalomethanes', data=water_data);
sns.violinplot(x="all", y="Trihalomethanes", hue="Potability", data=water_data, split=True)
plt.xlabel('Potability')
# Out:
# Text(0.5, 0, 'Potability')

# %%
water_data.isnull().sum().sum()
# Out:
# 0

# %%
potable = water_data[water_data['Potability'] == 1]
nonpotable = water_data[water_data['Potability'] == 0]

# %%
X = water_data.drop(columns = ['Potability', 'all'])
y = water_data['Potability']
print(X)
# Out:
#              ph    Hardness        Solids  Chloramines     Sulfate  \
# 3      8.316766  214.373394  22018.417441     8.059332  356.886136
# 4      9.092223  181.101509  17978.986339     6.546600  310.135738
# 5      5.584087  188.313324  28748.687739     7.544869  326.678363
# 6     10.223862  248.071735  28749.716544     7.513408  393.663396
# 7      8.635849  203.361523  13672.091764     4.563009  303.309771
# ...         ...         ...           ...          ...         ...
# 3267   8.989900  215.047358  15921.412018     6.297312  312.931022
# 3268   6.702547  207.321086  17246.920347     7.708117  304.510230
# 3269  11.491011   94.812545  37188.826022     9.263166  258.930600
# 3270   6.069616  186.659040  26138.780191     7.747547  345.700257
# 3271   4.668102  193.681735  47580.991603     7.166639  359.948574
#
#       Conductivity  Organic_carbon  Trihalomethanes  Turbidity
# 3       363.266516       18.436524       100.341674   4.628771
# ...

# %%
X_train, X_test, y_train, y_test = train_test_split(X , y, test_size = 0.5)

# %%
model = DecisionTreeClassifier()
#model.fit(X, y)
#model.predict([[7, 210, 14000, 5, 310, 470, 15, 80, 4.5]])
model.fit(X_train, y_train)
predictions = model.predict(X_test)

# %%
print("Model accuracy:", accuracy_score(y_test, predictions))
# Out:
# Model accuracy: 0.588469184890656

# %%
dummies = pd.get_dummies((water_data))
scaler = StandardScaler()
scaled_water = scaler.fit_transform(dummies)

# %%
model = KNeighborsClassifier()
# evaluate the model
cv = RepeatedStratifiedKFold(n_splits=10, n_repeats=3, random_state=1)
n_scores = cross_val_score(scaled_water, X, y, scoring='accuracy', cv=cv, n_jobs=-1, error_score='raise')
# report model performance
print('Accuracy: %.3f (%.3f)' % (mean(n_scores), std(n_scores)))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-164-f44af85c70cf> in <module>
#       2 # evaluate the model
#       3 cv = RepeatedStratifiedKFold(n_splits=10, n_repeats=3, random_state=1)
# ----> 4 n_scores = cross_val_score(scaled_water, X, y, scoring='accuracy', cv=cv, n_jobs=-1, error_score='raise')
#       5 # report model performance
#       6 print('Accuracy: %.3f (%.3f)' % (mean(n_scores), std(n_scores)))
#
# ~\PythonConda\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# ...
